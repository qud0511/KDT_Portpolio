# %% [markdown]
# # 데이터 가공

# %%
import pandas as pd
import openpyxl as op

PATH='C:\\Users\\whrjs\\PycharmProjects\\exam\\project2\\sec_pro\\yefire'

fire15=pd.read_csv(PATH+'2015.csv',encoding='cp949')
fire16=pd.read_csv(PATH+'2016.csv',encoding='cp949')
fire17=pd.read_csv(PATH+'2017.csv',encoding='cp949')
fire18=pd.read_csv(PATH+'2018.csv',encoding='cp949')
fire19=pd.read_csv(PATH+'2019.csv',encoding='cp949')
fire15.rename(columns={'발화열원':'발화열원대분류'},inplace=True)
fire16.rename(columns={'발화열원':'발화열원대분류'},inplace=True)
fire17.rename(columns={'발화열원':'발화열원대분류'},inplace=True)
fire18.rename(columns={'발화열원':'발화열원대분류'},inplace=True)
fire19.rename(columns={'시·군·구':'시군구'},inplace=True)

fire15=fire15[fire15.columns[1:]]
fire16=fire16[fire16.columns[1:]]
fire17=fire17[fire17.columns[1:]]
fire18=fire18[fire18.columns[1:]]

fireall=pd.concat([fire15,fire16,fire17,fire18,fire19])

fireall
# Out:
#        사망  부상  인명피해(명)소계  재산피해소계           화재발생년월일       시도   시군구   읍면동  \
# 0       0   0          0    2920  2015-01-01 00:01     경상남도   합천군   청덕면
# 1       0   0          0       0  2015-01-01 00:06    서울특별시  영등포구  여의도동
# 2       0   0          0     137  2015-01-01 00:07    서울특별시   강남구   논현동
# 3       0   0          0     326  2015-01-01 00:08    서울특별시   도봉구   쌍문동
# 4       0   0          0       0  2015-01-01 00:11    부산광역시   연제구   연산동
# ...    ..  ..        ...     ...               ...      ...   ...   ...
# 40098   0   0          0   23707  2019-12-31 22:33      경기도   파주시   광탄면
# 40099   0   0          0    3542  2019-12-31 22:45     경상북도   경산시   남방동
# 40100   0   0          0       0  2019-12-31 22:47    부산광역시    남구   문현동
# 40101   0   0          0     105  2019-12-31 23:05  제주특별자치도   제주시  외도일동
# 40102   0   0          0    3879  2019-12-31 23:18    인천광역시   남동구   고잔동
#
#            화재유형    발화열원대분류     발화열원소분류 발화요인대분류       발화요인소분류   최초착화물대분류  \
# ...

# %%
fireall.index=range(214467)
fireall
# Out:
#         사망  부상  인명피해(명)소계  재산피해소계           화재발생년월일       시도   시군구   읍면동  \
# 0        0   0          0    2920  2015-01-01 00:01     경상남도   합천군   청덕면
# 1        0   0          0       0  2015-01-01 00:06    서울특별시  영등포구  여의도동
# 2        0   0          0     137  2015-01-01 00:07    서울특별시   강남구   논현동
# 3        0   0          0     326  2015-01-01 00:08    서울특별시   도봉구   쌍문동
# 4        0   0          0       0  2015-01-01 00:11    부산광역시   연제구   연산동
# ...     ..  ..        ...     ...               ...      ...   ...   ...
# 214462   0   0          0   23707  2019-12-31 22:33      경기도   파주시   광탄면
# 214463   0   0          0    3542  2019-12-31 22:45     경상북도   경산시   남방동
# 214464   0   0          0       0  2019-12-31 22:47    부산광역시    남구   문현동
# 214465   0   0          0     105  2019-12-31 23:05  제주특별자치도   제주시  외도일동
# 214466   0   0          0    3879  2019-12-31 23:18    인천광역시   남동구   고잔동
#
#             화재유형    발화열원대분류     발화열원소분류 발화요인대분류       발화요인소분류   최초착화물대분류  \
# ...

# %%
fireall['화재발생년월일']=fireall['화재발생년월일'].astype('str')
fireall['화재발생년월일'].dtypes
# Out:
# dtype('O')

# %%
fire_list=fireall['화재발생년월일'].str.split('-')
fire_list.head()
# Out:
# 0    [2015, 01, 01 00:01]
# 1    [2015, 01, 01 00:06]
# 2    [2015, 01, 01 00:07]
# 3    [2015, 01, 01 00:08]
# 4    [2015, 01, 01 00:11]
# Name: 화재발생년월일, dtype: object

# %%
fireall['년']=fire_list.str.get(0)
fireall['월']=fire_list.str.get(1)
fireall['시간대']=fire_list.str.get(2)
fireall.head()
# Out:
#    사망  부상  인명피해(명)소계  재산피해소계           화재발생년월일     시도   시군구   읍면동      화재유형  \
# 0   0   0          0    2920  2015-01-01 00:01   경상남도   합천군   청덕면    건축,구조물
# 1   0   0          0       0  2015-01-01 00:06  서울특별시  영등포구  여의도동        임야
# 2   0   0          0     137  2015-01-01 00:07  서울특별시   강남구   논현동  자동차,철도차량
# 3   0   0          0     326  2015-01-01 00:08  서울특별시   도봉구   쌍문동    건축,구조물
# 4   0   0          0       0  2015-01-01 00:11  부산광역시   연제구   연산동    건축,구조물
#
#      발화열원대분류  ... 발화요인대분류      발화요인소분류   최초착화물대분류       최초착화물소분류     장소대분류  \
# 0       작동기기  ...  전기적 요인  접촉불량에 의한 단락      전기,전자           전선피복        주거
# 1  담뱃불, 라이터불  ...     부주의         담배꽁초         기타             기타        임야
# 2  담뱃불, 라이터불  ...     부주의         담배꽁초     침구,직물류     기타(침구,직물류)  자동차,철도차량
# 3  담뱃불, 라이터불  ...     부주의         담배꽁초  종이,목재,건초등  기타(종이,목재,건초등)   판매,업무시설
# 4       작동기기  ...     부주의      음식물 조리중         식품            음식물        주거
#
#   장소중분류  장소소분류     년   월       시간대
# ...

# %%
fireall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214467 entries, 0 to 214466
# Data columns (total 21 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   사망         214467 non-null  int64
#  1   부상         214467 non-null  int64
#  2   인명피해(명)소계  214467 non-null  int64
#  3   재산피해소계     214467 non-null  int64
#  4   화재발생년월일    214467 non-null  object
#  5   시도         214467 non-null  object
#  6   시군구        214467 non-null  object
#  7   읍면동        214436 non-null  object
#  8   화재유형       214467 non-null  object
#  9   발화열원대분류    214467 non-null  object
#  10  발화열원소분류    214467 non-null  object
#  11  발화요인대분류    214467 non-null  object
#  12  발화요인소분류    214467 non-null  object
#  13  최초착화물대분류   214467 non-null  object
#  14  최초착화물소분류   214467 non-null  object
#  15  장소대분류      214467 non-null  object
#  16  장소중분류      214467 non-null  object
#  17  장소소분류      214467 non-null  object
#  18  년          214467 non-null  object
# ...

# %% [markdown]
# for idx in range(0,214467):
#     fireall['시간대2']=fireall.시간대[idx][3:5]
# fireall['시간대2']

# %%
for idx in range(len(fireall.시간대)):
    if 0<=int(fireall.시간대[idx][3:5])<6:
        fireall.시간대[idx]='심야'
    elif 6<=int(fireall.시간대[idx][3:5])<12:
        fireall.시간대[idx]='아침'
    elif 12<=int(fireall.시간대[idx][3:5])<18:
        fireall.시간대[idx]='낮'
    elif 18<=int(fireall.시간대[idx][3:5])<24:
        fireall.시간대[idx]='저녁'
# Out:
# C:\Users\whrjs\AppData\Local\Temp\ipykernel_16880\3053483478.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fireall.시간대[idx]='심야'
# C:\Users\whrjs\AppData\Local\Temp\ipykernel_16880\3053483478.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fireall.시간대[idx]='아침'
# C:\Users\whrjs\AppData\Local\Temp\ipykernel_16880\3053483478.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fireall.시간대[idx]='낮'
# ...

# %%
fireall
# Out:
#         사망  부상  인명피해(명)소계  재산피해소계           화재발생년월일       시도   시군구   읍면동  \
# 0        0   0          0    2920  2015-01-01 00:01     경상남도   합천군   청덕면
# 1        0   0          0       0  2015-01-01 00:06    서울특별시  영등포구  여의도동
# 2        0   0          0     137  2015-01-01 00:07    서울특별시   강남구   논현동
# 3        0   0          0     326  2015-01-01 00:08    서울특별시   도봉구   쌍문동
# 4        0   0          0       0  2015-01-01 00:11    부산광역시   연제구   연산동
# ...     ..  ..        ...     ...               ...      ...   ...   ...
# 214462   0   0          0   23707  2019-12-31 22:33      경기도   파주시   광탄면
# 214463   0   0          0    3542  2019-12-31 22:45     경상북도   경산시   남방동
# 214464   0   0          0       0  2019-12-31 22:47    부산광역시    남구   문현동
# 214465   0   0          0     105  2019-12-31 23:05  제주특별자치도   제주시  외도일동
# 214466   0   0          0    3879  2019-12-31 23:18    인천광역시   남동구   고잔동
#
#             화재유형    발화열원대분류  ... 발화요인대분류       발화요인소분류   최초착화물대분류  \
# ...

# %%
fireall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214467 entries, 0 to 214466
# Data columns (total 21 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   사망         214467 non-null  int64
#  1   부상         214467 non-null  int64
#  2   인명피해(명)소계  214467 non-null  int64
#  3   재산피해소계     214467 non-null  int64
#  4   화재발생년월일    214467 non-null  object
#  5   시도         214467 non-null  object
#  6   시군구        214467 non-null  object
#  7   읍면동        214436 non-null  object
#  8   화재유형       214467 non-null  object
#  9   발화열원대분류    214467 non-null  object
#  10  발화열원소분류    214467 non-null  object
#  11  발화요인대분류    214467 non-null  object
#  12  발화요인소분류    214467 non-null  object
#  13  최초착화물대분류   214467 non-null  object
#  14  최초착화물소분류   214467 non-null  object
#  15  장소대분류      214467 non-null  object
#  16  장소중분류      214467 non-null  object
#  17  장소소분류      214467 non-null  object
#  18  년          214467 non-null  object
# ...

# %%
fireall=fireall[['년','월','시간대','시도','화재유형','발화열원대분류','발화요인대분류','최초착화물대분류','장소대분류',
                 '사망','부상','인명피해(명)소계','재산피해소계']]

# %%
fireall
# Out:
#            년   월 시간대       시도      화재유형    발화열원대분류 발화요인대분류   최초착화물대분류  \
# 0       2015  01  심야     경상남도    건축,구조물       작동기기  전기적 요인      전기,전자
# 1       2015  01  심야    서울특별시        임야  담뱃불, 라이터불     부주의         기타
# 2       2015  01  심야    서울특별시  자동차,철도차량  담뱃불, 라이터불     부주의     침구,직물류
# 3       2015  01  심야    서울특별시    건축,구조물  담뱃불, 라이터불     부주의  종이,목재,건초등
# 4       2015  01  심야    부산광역시    건축,구조물       작동기기     부주의         식품
# ...      ...  ..  ..      ...       ...        ...     ...        ...
# 214462  2019  12  저녁      경기도    건축,구조물       작동기기  전기적 요인      전기,전자
# 214463  2019  12  저녁     경상북도    건축,구조물         미상      미상  종이,목재,건초등
# 214464  2019  12  저녁    부산광역시    건축,구조물       작동기기     부주의         식품
# 214465  2019  12  저녁  제주특별자치도    건축,구조물       작동기기     부주의       합성수지
# 214466  2019  12  저녁    인천광역시    건축,구조물       작동기기  전기적 요인      전기,전자
#
#            장소대분류  사망  부상  인명피해(명)소계  재산피해소계
# 0             주거   0   0          0    2920
# ...

# %%
fireall.to_excel('./fire_allyear.xlsx')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py:999, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     998 try:
# --> 999     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1000     if engine == "auto":
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py:256, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     255 def __call__(self, *args, **kwds):
# --> 256     return self.__func__(*args, **kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_config\config.py:128, in _get_option(pat, silent)
#     127 def _get_option(pat: str, silent: bool = False):
# --> 128     key = _get_single_key(pat, silent)
#     130     # walk the nested dict
#
# ...

# %%
fireall.to_csv('./fire_allyear.csv', encoding="CP949", index=False)
